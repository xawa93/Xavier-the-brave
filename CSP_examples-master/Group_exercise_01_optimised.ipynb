# %%
"""
Program written by Jordan Bruno
Module: CSP
This program is extremely inefficient and should provide you wish numerous opportunities to optimise the code.
"""

import timeit

#print(timeit.timeit("""

# this function checks the customers age and limits the drinks they can purchase if they are not an adult.
def check_age(age, list_of_drinks):
    global new_list_of_drinks
    new_list_of_drinks = []
    if age >= 18:
        new_list_of_drinks = list_of_drinks  
    else:
        new_list_of_drinks = []
        #removed the if else construct and replaced it with a set (O(n/2))
        for i in range(len(list_of_drinks)):
            if list_of_drinks[i] in alcoholic_set:
                print(f"You are not old enough to purchase {list_of_drinks[i]}, {list_of_drinks[i]} removed from order.")
            else:
                new_list_of_drinks.append(list_of_drinks[i])  
                
            
# this function checks if the customer has enough tokens to purchase all the items they wish
# if the customer does not have enough tokens their order is reduced to an order they have enough tokens to buy
def check_tokens(tokens, list_of_drinks):
    global new_list_of_drinks
    new_list_of_drinks = []
    #replaced "while" with "if"
    if tokens > 5:
        print("There is a 5 token limit")
        tokens = 5
    #check if tokens is 0
    elif tokens == 0:
        print("Not enough tokens")
    
    #replaced 30 lines of code with 5
    if len(list_of_drinks) <= tokens:
        new_list_of_drinks = list_of_drinks
    else:
        print("You do not have any tokens to purchase a drink")
        new_list_of_drinks = list_of_drinks[:tokens]

            
# this function counts the amount of alcoholic units in the customers order and stops them purchasing more once over the limit
def check_limit(list_of_drinks):
    global new_list_of_drinks
    new_list_of_drinks = []
    unit_count = 0
    #create a set of all drinks and join the sets (union technique)
    all_set = {'coke'}
    allset = set(all_set) & set(alcoholic_set)
    #iterate over all drinks in the list
    for i in range(len(list_of_drinks)):
        #if the next drink would surpass the drinking limit -> go straight to the else block
        if (unit_count + drinks[list_of_drinks[i]]) <= 15:
            #dictionary lookup of the unit number
            unit_count += drinks[list_of_drinks[i]]
            new_list_of_drinks.append(list_of_drinks[i])
        else:
            print(f"I cant give you another {list_of_drinks[i]} , I think you've had enough to drink today")
    return new_list_of_drinks

# this function uses the three functions above to show the entire customer process of purchasing drinks
def order_drinks(age, tokens, list_of_drinks):
    check_age(age, list_of_drinks)
    check_tokens(tokens, new_list_of_drinks)
    check_limit(new_list_of_drinks)
    return new_list_of_drinks

# variables       
tokens, age, limit = 20, 17, 15
list_of_drinks = ["manhattan" , "manhattan", "bourbon_sour", "bourbon_sour"]

# these are the alcoholic unit values for each of the drinks
#replaced by a dictionary
drinks = {'coke':0, 'martini':3.5, 'old_fashioned':5, 'mojito':3, 'manhattan':4.5, 'bourbon_sour':5.5, 'heineken':1, 'strongbow_gold':1.5}

alcoholic_set = {'old_fashioned', 'martini', 'mojito', 'manhattan', 'bourbon_sour', 'heineken', 'strongbow_gold'}

#coke = 0
#martini = 3.5
#old_fashioned = 5
#mojito = 3
#manhattan = 4.5
#bourbon_sour = 5.5
#heineken = 1
#strongbow_gold = 1.5

# I recommend running the functions below one at a time, you can do this by commenting them out with a '#'.
# descriptions of what is being tested included on the right, try to predict the results, are they what you expected?

#print(order_drinks(15, 5, ["old_fashioned", "mojito", "manhattan", "coke", "coke"])) # customer is a child (15)
#print(order_drinks(20, 0, ["manhattan" , "manhattan", "bourbon_sour", "bourbon_sour"])) # customer has no tokens 
#print(order_drinks(25, 3, ["manhattan" , "manhattan", "bourbon_sour", "bourbon_sour"])) # customer has less tokens than drink orders
#print(order_drinks(18, 2, ["heineken", "heineken"])) # customer has enough tokens for drink orders
#print(order_drinks(21, 7, ["coke", "martini", "old_fashioned", "mojito", "manhattan", "bourbon_sour", "heineken", "strongbow_gold"])) # customer has more than 5 tokens and more than 5 orders
#print(order_drinks(30, 10, ["old_fashioned", "mojito", "manhattan"])) # customer has more than 5 tokens but less than 5 orders
print(order_drinks(85, 5, ["bourbon_sour", "bourbon_sour", "bourbon_sour", "bourbon_sour", "bourbon_sour"]))# customer is a hardcore drunk


#These are the drinks that the program will allow, incase you wanted to test your own function criteria...
#"coke", "martini", "old_fashioned", "mojito", "manhattan", "bourbon_sour", "heineken", "strongbow_gold"

#""", number = 10000))
# Out:
# I cant give you another bourbon_sour , I think you've had enough to drink today
# I cant give you another bourbon_sour , I think you've had enough to drink today
# I cant give you another bourbon_sour , I think you've had enough to drink today
# ['bourbon_sour', 'bourbon_sour']

# %%
print(timeit.timeit("""

# this function checks the customers age and limits the drinks they can purchase if they are not an adult.
def check_age_original(age, list_of_drinks):
    global new_list_of_drinks
    if age >= 18:
        new_list_of_drinks = list_of_drinks  
    else:
        new_list_of_drinks = []
        for i in range(len(list_of_drinks)):
            if list_of_drinks[i] == "martini":
                print(f"You are not old enough to purchase {list_of_drinks[i]}, {list_of_drinks[i]} removed from order.")
            elif list_of_drinks[i] == "old fashioned":
                print(f"You are not old enough to purchase {list_of_drinks[i]}, {list_of_drinks[i]} removed from order.")
            elif list_of_drinks[i] == "mojito":
                print(f"You are not old enough to purchase {list_of_drinks[i]}, {list_of_drinks[i]} removed from order.")
            elif list_of_drinks[i] == "manhattan":
                print(f"You are not old enough to purchase {list_of_drinks[i]}, {list_of_drinks[i]} removed from order.")
            elif list_of_drinks[i] == "bourbon sour":
                print(f"You are not old enough to purchase {list_of_drinks[i]}, {list_of_drinks[i]} removed from order.")
            elif list_of_drinks[i] == "heineken":
                print(f"You are not old enough to purchase {list_of_drinks[i]}, {list_of_drinks[i]} removed from order.")
            elif list_of_drinks[i] == "strongbow gold":
                print(f"You are not old enough to purchase {list_of_drinks[i]}, {list_of_drinks[i]} removed from order.")
            else:
                new_list_of_drinks.append(list_of_drinks[i])              
            
# this function checks if the customer has enough tokens to purchase all the items they wish
# if the customer does not have enough tokens their order is reduced to an order they have enough tokens to buy
def check_tokens_original(tokens, list_of_drinks):
    global new_list_of_drinks
    new_list_of_drinks = []
    while tokens > 5:
        print("There is a 5 token limit")
        tokens = 5
    else:
        if tokens == 5:
            if len(list_of_drinks) <= tokens:
                new_list_of_drinks = list_of_drinks
            else:
                print("Not enough tokens")
                new_list_of_drinks = list_of_drinks[:5]
        elif tokens == 4:
            if len(list_of_drinks) <= tokens:
                new_list_of_drinks = list_of_drinks
            else:
                print("Not enough tokens")
                new_list_of_drinks = list_of_drinks[:4]
        elif tokens == 3:
            if len(list_of_drinks) <= tokens:
                new_list_of_drinks = list_of_drinks
            else:
                print("Not enough tokens")
                new_list_of_drinks = list_of_drinks[:3]
        elif tokens == 2:
            if len(list_of_drinks) <= tokens:
                new_list_of_drinks = list_of_drinks
            else:
                print("Not enough tokens")
                new_list_of_drinks = list_of_drinks[:2]
        elif tokens == 1:
            if len(list_of_drinks) <= tokens:
                new_list_of_drinks = list_of_drinks
            else:
                print("Not enough tokens")
                new_list_of_drinks = list_of_drinks[:1]
        else:
            print("You do not have any tokens to purchase a drink")
            
# this function counts the amount of alcoholic units in the customers order and stops them purchasing more once over the limit
def check_limit_original(list_of_drinks):
    global new_list_of_drinks
    new_list_of_drinks = []
    unit_count = 0
    for i in range(len(list_of_drinks)):
        if unit_count <= 15:
            if list_of_drinks[i] == "coke":
                unit_count += coke
                new_list_of_drinks.append(list_of_drinks[i])
            if list_of_drinks[i] == "martini":
                unit_count += martini
                new_list_of_drinks.append(list_of_drinks[i])
            if list_of_drinks[i] == "old fashioned":
                unit_count += old_fashioned
                new_list_of_drinks.append(list_of_drinks[i])
            if list_of_drinks[i] == "mojito":
                unit_count += mojito
                new_list_of_drinks.append(list_of_drinks[i])
            if list_of_drinks[i] == "manhattan":
                unit_count += manhattan
                new_list_of_drinks.append(list_of_drinks[i])
            if list_of_drinks[i] == "bourbon sour":
                unit_count += bourbon_sour
                new_list_of_drinks.append(list_of_drinks[i])
            if list_of_drinks[i] == "heineken":
                unit_count += heineken
                new_list_of_drinks.append(list_of_drinks[i])
            if list_of_drinks[i] == "strongbow gold":
                unit_count += strongbow_gold
                new_list_of_drinks.append(list_of_drinks[i])
        else:
            print(f"I cant give you another {list_of_drinks[i]} , I think you've had enough to drink today")
    return new_list_of_drinks

# this function uses the three functions above to show the entire customer process of purchasing drinks
def order_drinks_original(age, tokens, list_of_drinks):
    check_age_original(age, list_of_drinks)
    check_tokens_original(tokens, new_list_of_drinks)
    check_limit_original(new_list_of_drinks)
    return new_list_of_drinks

# variables       
tokens = 20
age = 17
list_of_drinks = ["manhattan" , "manhattan", "bourbon sour", "bourbon sour"]
limit = 15

# these are the alcoholic unit values for each of the drinks
coke = 0
martini = 3.5
old_fashioned = 5
mojito = 3
manhattan = 4.5
bourbon_sour = 5.5
heineken = 1
strongbow_gold = 1.5

# I recommend running the functions below one at a time, you can do this by commenting them out with a '#'.
# descriptions of what is being tested included on the right, try to predict the results, are they what you expected?

#print(order_drinks_original(15, 5, ["old fashioned", "mojito", "manhattan", "coke", "coke"])) # customer is a child (15)
#print(order_drinks_original(20, 0, ["manhattan" , "manhattan", "bourbon sour", "bourbon sour"])) # customer has no tokens 
#print(order_drinks_original(25, 3, ["manhattan" , "manhattan", "bourbon sour", "bourbon sour"])) # customer has less tokens than drink orders
#print(order_drinks_original(18, 2, ["heineken", "heineken"])) # customer has enough tokens for drink orders
#print(order_drinks_original(21, 7, ["coke", "martini", "old fashioned", "mojito", "manhattan", "bourbon sour", "heineken", "strongbow gold"])) # customer has more than 5 tokens and more than 5 orders
#print(order_drinks_original(30, 10, ["old fashioned", "mojito", "manhattan"])) # customer has more than 5 tokens but less than 5 orders
print(order_drinks_original(85, 5, ["bourbon sour", "bourbon sour", "bourbon sour", "bourbon sour", "bourbon sour"]))# customer is a hardcore drunk


#These are the drinks that the program will allow, incase you wanted to test your own function criteria...
#"coke", "martini", "old fashioned", "mojito", "manhattan", "bourbon sour", "heineken", "strongbow gold"

""", number = 10000))
# Out:
# I cant give you another bourbon sour , I think you've had enough to drink today
# I cant give you another bourbon sour , I think you've had enough to drink today
# ['bourbon sour', 'bourbon sour', 'bourbon sour']
# I cant give you another bourbon sour , I think you've had enough to drink today
# I cant give you another bourbon sour , I think you've had enough to drink today
# ['bourbon sour', 'bourbon sour', 'bourbon sour']
# I cant give you another bourbon sour , I think you've had enough to drink today
# I cant give you another bourbon sour , I think you've had enough to drink today
# ['bourbon sour', 'bourbon sour', 'bourbon sour']
# I cant give you another bourbon sour , I think you've had enough to drink today
# I cant give you another bourbon sour , I think you've had enough to drink today
# ['bourbon sour', 'bourbon sour', 'bourbon sour']
# I cant give you another bourbon sour , I think you've had enough to drink today
# ...

# %%
setup = 'from __main__ import order_drinks, age, tokens, list_of_drinks; from __main__ import order_drinks_original, age, tokens, list_of_drinks; from timeit import timeit'
num = 10000
t2 = timeit('order_drinks_original(age, tokens, list_of_drinks)', setup=setup, number=num)
t1 = timeit('order_drinks(age, tokens, list_of_drinks)', setup=setup, number=num)
print('\n')
print('Time_new = ' + str(t1))
print('Time_original = ' + str(t2))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-49-b5566f95b229> in <module>
#       1 setup = 'from __main__ import order_drinks, age, tokens, list_of_drinks; from __main__ import order_drinks_original, age, tokens, list_of_drinks; from timeit import timeit'
#       2 num = 10000
# ----> 3 t2 = timeit('order_drinks_original(age, tokens, list_of_drinks)', setup=setup, number=num)
#       4 t1 = timeit('order_drinks(age, tokens, list_of_drinks)', setup=setup, number=num)
#       5 print('\n')
#
# TypeError: 'module' object is not callable
